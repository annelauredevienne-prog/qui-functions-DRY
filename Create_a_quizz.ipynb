# %%
# Welcome message
print("Here you have our quiz !")

correct_answer = "Elon Musk"
attempts = 0
max_attempts = 3

# 3 questions defined with always same anwser presented as list
questions = [
    ( "Who is the founder of Tesla?"),
    ("Which entrepreneur is famous with Tesla?"),
    ("Who is the director of SpacX?")
]

# Define the function calling all questions as a quiz
while answer_attempts != correct_answer and attempts < max_attempts:
    answer = input(question)
    attempts += 1

    def ask_question (question):
        answer_attempts = input(question)
        print(answer_attempts)
        if answer_attempts == correct_anser: 
            print("Good job! This is the right answer")
        elif attempts < max_attempts:
            print("Incorrect answer. You have {max_attempts - attempts} attempts left.")
        else:
            print("Too bad! That is not the correct answer")




# ask 3 questions - boucle
for question in questions:
        ask_question(question)
# Out:
# Here you have our quiz !
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 10
#       7 max_attempts = 3
#       9 # Define the function calling all questions as a quiz
# ---> 10 while answer_attempts != correct_answer and attempts < max_attempts:
#      11     answer = input(question)
#      12     attempts += 1
#
# NameError: name 'answer_attempts' is not defined
