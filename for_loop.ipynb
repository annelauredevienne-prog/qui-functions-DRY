# %%
items = ["Hello", "World", "From", "Jedha"]
print(items)
# Out:
# ['Hello', 'World', 'From', 'Jedha']

# %%
print(items[0])
print(items[1])
print(items[2])
print(items[3])
# Out:
# Hello
# World
# From
# Jedha

# %%
for item in items:
    print(item)
# Out:
# Hello
# World
# From
# Jedha

# %%
length = len(items)
for i in range (length):
    print(items[i])
# Out:
# Hello
# World
# From
# Jedha

# %%
for item in enumerate(items):
    print(item)
# Out:
# (0, 'Hello')
# (1, 'World')
# (2, 'From')
# (3, 'Jedha')

# %%
greetings = ["Hello", "World", "From", "Jedha"]
list = []
for i, value in enumerate(greetings):
    list.append((i + 10, value))
print (list)
# Out:
# [(10, 'Hello'), (11, 'World'), (12, 'From'), (13, 'Jedha')]

# %%
a =[1,2,3,"stop",4,5,6,7,8]
for i in a:
    if i == "stop":
        break
    print (i)
# Out:
# 1
# 2
# 3
