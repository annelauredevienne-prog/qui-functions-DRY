# %% [markdown]
# # House Market

# %% [markdown]
# Let's go a little further into python.

# %% [markdown]
# 1. Download the four files “superficie.csv” / “nombre_de_sdb.csv” / “nombre_de_chambres.csv” / "house_price.csv"
#
# 2. Read the files and create the 4 corresponding Dataframes

# %%
import pandas as pd

# %%
surface = pd.read_csv("/Users/anne-lauredevienne/Desktop/Introduction_to_python_for_data_science/superficie.csv", header=None)
bathrooms = pd.read_csv("/Users/anne-lauredevienne/Desktop/Introduction_to_python_for_data_science/nombre_de_sdb.csv", header=None)
rooms = pd.read_csv("/Users/anne-lauredevienne/Desktop/Introduction_to_python_for_data_science/nombre_de_chambres.csv", header=None)
house_price = pd.read_csv("/Users/anne-lauredevienne/Desktop/Introduction_to_python_for_data_science/house_price.csv", index_col=0)
# Out:
# Dossier existe ? False
# [PosixPath('/Users/anne-lauredevienne/Desktop/Introduction_to_python_for_data_science/02-Numpy_functions.ipynb'), PosixPath('/Users/anne-lauredevienne/Desktop/Introduction_to_python_for_data_science/02-Data_manipulation_with_Pandas.ipynb'), PosixPath('/Users/anne-lauredevienne/Desktop/Introduction_to_python_for_data_science/.DS_Store'), PosixPath('/Users/anne-lauredevienne/Desktop/Introduction_to_python_for_data_science/Tests_francois.ipynb'), PosixPath('/Users/anne-lauredevienne/Desktop/Introduction_to_python_for_data_science/02-Linear_algebra_with_numpy.ipynb'), PosixPath('/Users/anne-lauredevienne/Desktop/Introduction_to_python_for_data_science/02-House_market (2).ipynb'), PosixPath('/Users/anne-lauredevienne/Desktop/Introduction_to_python_for_data_science/test-'), PosixPath('/Users/anne-lauredevienne/Desktop/Introduction_to_python_for_data_science/01-EDA_pandas_Explore_a_database.ipynb'), PosixPath('/Users/anne-lauredevienne/Desktop/Introduction_to_python_for_data_science/manipulate_data_types.ipynb'), PosixPath('/Users/anne-lauredevienne/Desktop/Introduction_to_python_for_data_science/README.md'), PosixPath('/Users/anne-lauredevienne/Desktop/Introduction_to_python_for_data_science/superficie.csv'), PosixPath('/Users/anne-lauredevienne/Desktop/Introduction_to_python_for_data_science/nombre_de_chambres.csv'), PosixPath('/Users/anne-lauredevienne/Desktop/Introduction_to_python_for_data_science/.gitignore'), PosixPath('/Users/anne-lauredevienne/Desktop/Introduction_to_python_for_data_science/for_loop.ipynb'), PosixPath('/Users/anne-lauredevienne/Desktop/Introduction_to_python_for_data_science/tricount_project.ipynb'), PosixPath('/Users/anne-lauredevienne/Desktop/Introduction_to_python_for_data_science/variables.ipynb'), PosixPath('/Users/anne-lauredevienne/Desktop/Introduction_to_python_for_data_science/Create_a_password.ipynb'), PosixPath('/Users/anne-lauredevienne/Desktop/Introduction_to_python_for_data_science/03b-OPTIONAL_Calculate_interests.ipynb'), PosixPath('/Users/anne-lauredevienne/Desktop/Introduction_to_python_for_data_science/01-Numpy_linear_algebra (1).ipynb'), PosixPath('/Users/anne-lauredevienne/Desktop/Introduction_to_python_for_data_science/.git'), PosixPath('/Users/anne-lauredevienne/Desktop/Introduction_to_python_for_data_science/Create_a_quizz.ipynb'), PosixPath('/Users/anne-lauredevienne/Desktop/Introduction_to_python_for_data_science/house_price.csv'), PosixPath('/Users/anne-lauredevienne/Desktop/Introduction_to_python_for_data_science/nombre_de_sdb.csv'), PosixPath('/Users/anne-lauredevienne/Desktop/Introduction_to_python_for_data_science/test.ipynb'), PosixPath('/Users/anne-lauredevienne/Desktop/Introduction_to_python_for_data_science/01-Data_manipulation_with_numpy.ipynb'), PosixPath('/Users/anne-lauredevienne/Desktop/Introduction_to_python_for_data_science/classe_garage.ipynb')]
# Desktop existe ? True
# Contenu du Desktop :
# [PosixPath('/Users/anne-lauredevienne/Desktop/Introduction_to_python_for_data_science'), PosixPath('/Users/anne-lauredevienne/Desktop/.DS_Store'), PosixPath('/Users/anne-lauredevienne/Desktop/Vs code-training'), PosixPath('/Users/anne-lauredevienne/Desktop/02a-Math_oriented_programming.ipynb')]
# /Users/anne-lauredevienne/Desktop/Introduction_to_python_for_data_science/superficie.csv

# %%
print("Surface:")
display(surface.head())
print()
print("Bathrooms")
display(bathrooms.head())
print()
print("Rooms")
display(rooms.head())
print()
print("House prices")
display(house_price.head())
# Out:
# Surface:
#    0      1
# 0  0  28844
# 1  1  27667
# 2  2  14742
# 3  3  28089
# 4  4  11713
# Bathrooms
#    0  1
# 0  0  2
# 1  1  1
# 2  2  1
# 3  3  3
# 4  4  1
# Rooms
#    0  1
# 0  0  1
# 1  1  4
# 2  2  1
# 3  3  4
# 4  4  2
# House prices
#    id  house_price
# 0  14    1918154.0
# 1  30     739142.0
# 2  70    1621938.0
# 3  77    1319862.0
# 4  50     146250.0

# %% [markdown]
# 3. Give a column name to the three datasets that don't have a header in the source file

# %%
surface.columns = ['id', 'surface']
bathrooms.columns = ['id','bathrooms']
rooms.columns = ['id', 'rooms']

# %%
house_price.head()
# Out:
#    id  house_price
# 0  14    1918154.0
# 1  30     739142.0
# 2  70    1621938.0
# 3  77    1319862.0
# 4  50     146250.0

# %%
# Out:
#    id  house_price
# 0  14    1918154.0
# 1  30     739142.0
# 2  70    1621938.0
# 3  77    1319862.0
# 4  50     146250.0

# %% [markdown]
# 4. Make an inner join of these four datasets into a single dataframe.

# %%
dataset = surface.merge(bathrooms, on='id').merge(rooms, on='id').merge(house_price, on='id') # see documentation : merge performs an inner join by default

# %% [markdown]
# 5. What is the average surface area of the houses in our dataset?

# %%
dataset ["surface"].mean()
# Out:
# np.float64(20439.77)

# %% [markdown]
# 6. What is the median and average number of rooms?

# %%
print("The average number of room is {}, and the median number is {}"
      .format(dataset['rooms'].mean(), dataset['rooms'].median()))
# Out:
# The average number of room is 2.42, and the median number is 2.0

# %% [markdown]
# 7. What is the average cost of a house?

# %%
dataset ["house_price"].mean()
# Out:
# np.float64(767747.87)

# %% [markdown]
# 8. What is the average cost of a house, depending on the number of rooms it has?

# %%
dataset.groupby("rooms")["house_price"].mean()
# Out:
# rooms
# 1    980774.869565
# 2    642086.258065
# 3    645904.592593
# 4    888045.631579
# Name: house_price, dtype: float64

# %% [markdown]
# 10. The average cost per room doesn't tell us much. Let's try to categorize by size.
#
#   - Create a new column in your dataset that we'll call home_size
# Create five categories that respectively correspond to:
#       - "very large" $=$ "a house larger than 25,000 sqrt_feet"
#       - "large" $=$ "a house between 20,000 and 25,000 sqrt_feet"
#       - "medium" $=$ "a house between 15,000 and 20,000 sqrt_feet"
#       - "small" $=$ "a house between 10,000 and 15,000 sqrt_feet"
#       - "very small" $=$ a house less than 10,000 sqrt_feet"
#
# Fill in the corresponding rows in the house_size column.

# %%
def categories(taille):
    if taille > 25000:
        return "very large"
    elif taille > 20000:
        return "large"
    elif taille > 15000:
        return "medium"
    elif taille > 10000:
        return "small"
    else:
        return "very small"

dataset ["house_size"] =dataset ["surface"].apply(categories) 
display(dataset)
# Out:
#     id  surface  bathrooms  rooms  house_price  house_size
# 0    0    28844          2      1    1421908.0  very large
# 1    1    27667          1      4    1305091.0  very large
# 2    2    14742          1      1     164373.0       small
# 3    3    28089          3      4    1441714.0  very large
# 4    4    11713          1      2     108290.0       small
# ..  ..      ...        ...    ...          ...         ...
# 95  95    11417          3      3     132599.0       small
# 96  96    12126          1      2     155828.0       small
# 97  97    16390          1      2     237061.0      medium
# 98  98    23738          1      2     976422.0       large
# 99  99    14613          2      2     183621.0       small
#
# [100 rows x 6 columns]

# %% [markdown]
# 11. What is the average cost of a house depending on its size category?

# %%
dataset.groupby("house_size")["house_price"].mean()
# Out:
# house_size
# large         7.325385e+05
# medium        3.256948e+05
# small         1.561387e+05
# very large    1.552456e+06
# Name: house_price, dtype: float64

# %% [markdown]
#  12. Apply the code below to view your result. What can you conclude?

# %%
import plotly.express as px
fig = px.scatter(dataset, x = "surface", y = "house_price", trendline = "ols")
fig.show()
