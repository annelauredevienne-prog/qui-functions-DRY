# %%
print("Total number of friends: {}".format(total_number_of_friends))
print("Total_amount_spent: {}".format(total_amount_spent))
# Out:
# Total number of friends: 5
# Total_amount_spent: 350

# %%
a=10

print(a + 15)
print(a - 5)
print(a * 2)
print(a / 2)
print(a ** 2)
# Out:
# 25
# 5
# 20
# 5.0
# 100

# %%
b=32
print(a + b)
print(a / b)
print(a ** b)
# Out:
# 42
# 0.3125
# 100000000000000000000000000000000

# %%
c = a * b
print(c)
# Out:
# 320

# %%
total_number_of_friends = input("How many friends traveled with you?")
total_amount_spent = input("How much did you spend during your trip?")

print(total_number_of_friends)
print(total_amount_spent)
# Out:
# 5
# 350

# %%
total_amount_spent / total_number_of_friends
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 total_amount_spent / total_number_of_friends
#
# TypeError: unsupported operand type(s) for /: 'str' and 'str'

# %%
type(total_amount_spent)
# Out:
# str

# %%
total_amount_spent + total_number_of_friends
# Out:
# '3505'

# %%
total_amount_spent = int(total_amount_spent)
total_number_of_friends = int (total_number_of_friends)

split_amount = total_amount_spent / total_number_of_friends
print("Each person should pay: {}$".format(split_amount))
# Out:
# Each person should pay: 70.0$
